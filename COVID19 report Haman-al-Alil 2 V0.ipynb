# %%
from IPython.display import HTML, display, Image
from preprocess import read_preprocess_file
from tables import *
from plots import *
import os
#load in the unmitigated simulation
camp_name='Haman-al-Alil'
baseline=read_preprocess_file(os.path.join('model_outcomes','Haman-al-Alil','baseline.csv'),camp_name)

# %% [markdown]
# #### Disclaimer: This report is a draft report from AI for Good Simulator on the COVID-19 situation in Hamnan-al-Alil 2 camp, Iraq. The insights are preliminary and they are subject to future model fixes and improvements on parameter values

# %% [markdown]
# # AI for Good Simulator Model Report for Moria Camp

# %% [markdown]
# ## 0. Glossary
# * **hospitalisation/critical care demand person days**: The residents go into the hospitalisation/critical stage signify they require care but they may not receive the care depending on the capacity so this aggregates the hospitalisation/critical demand by person times number of days. If a unit cost of care is known, the total medical expense can be calculated.
# * **IQR (interquartile range)**: The output of modelling are represented as Interquartile range representing a confidence interval of 25%-75%.

# %% [markdown]
# ## 1. Overview

# %% [markdown]
# This report provides simulation-based estimates for COVID-19 epidemic scenarios for the Haman-al-Alil 2 camp, an IDP camp located in Iraq There are an estimated 10,000 people currently living in the camp. Through epidemiology simulations, we estimated peak counts, the timing of peak counts as well as cumulative counts for new symptomatic cases, hospitalisation demand person-days, critical care demand person-days and deaths for an unmitigated epidemic.  Then we compare the results with different combinations of intervention strategies in place to:
# * Compare the potential efficacies of different interventions and prioritise the ones that are going to help contain the virus.
# * Have a realistic estimate of the clinic capacity, PPE, ICU transfer and other supplies and logistical measures needed

# %% [markdown]
# The graph below represents the disease transition dynamics for each individual included in the modelling studies. The model we use is a deterministic, age-specific compartment model. We produce the analysis based on 1000 simulation runs over a range of possible parameters

# %%
Image(filename='model.png',width=700,height=700) #not the most up-to-date diagram pending an update

# %% [markdown]
# The deterministic compartmental model requires:
# * Camp specific parameters: population size and age structure of the residents.
# * COVID specific parameters*: asymptomatic infection rate, days remaining infectious, etc.

# %%
population_breakdown(camp_name)
# Out:
# <style  type="text/css" >
#     #T_e994af68_b739_11ea_9ecb_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_e994af68_b739_11ea_9ecb_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_e994af68_b739_11ea_9ecb_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_e994af68_b739_11ea_9ecb_acbc32839263" ><caption>Population breakdown of Hamam-al-Alil 2 camp with 9465 residents</caption><thead>    <tr>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Population_structure</th>        <th class="col_heading level0 col2" >Number of residents</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row0_col0" class="data row0 col0" >0-9</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row0_col1" class="data row0 col1" >36.1%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row0_col2" class="data row0 col2" >3419</td>
#             </tr>
#             <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row1_col0" class="data row1 col0" >10-19</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row1_col1" class="data row1 col1" >27.8%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row1_col2" class="data row1 col2" >2632</td>
#             </tr>
#             <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row2_col0" class="data row2 col0" >20-29</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row2_col1" class="data row2 col1" >11.9%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row2_col2" class="data row2 col2" >1126</td>
#             </tr>
#             <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row3_col0" class="data row3 col0" >30-39</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row3_col1" class="data row3 col1" >9.5%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row3_col2" class="data row3 col2" >898</td>
#             </tr>
#             <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row4_col0" class="data row4 col0" >40-49</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row4_col1" class="data row4 col1" >7.7%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row4_col2" class="data row4 col2" >724</td>
#             </tr>
#             <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row5_col0" class="data row5 col0" >50-59</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row5_col1" class="data row5 col1" >4.3%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row5_col2" class="data row5 col2" >409</td>
#             </tr>
#             <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row6_col0" class="data row6 col0" >60-69</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row6_col1" class="data row6 col1" >1.8%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row6_col2" class="data row6 col2" >171</td>
#             </tr>
#             <tr>
#                                 <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row7_col0" class="data row7 col0" >70+</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row7_col1" class="data row7 col1" >0.9%</td>
#                         <td id="T_e994af68_b739_11ea_9ecb_acbc32839263row7_col2" class="data row7 col2" >85</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# In Haman-al-Alil, it is estimated that 75% of the residents are below the age of 30 and that will lead to a relatively low death numbers but a high number of assympomatic infections.

# %% [markdown]
# Epidemiology simulations produce peak prevalence, the timing of peak prevalence as well as cumulative incidences for:
# * Symptomatic cases of infection
# * Hospitalisation demand person-days
# * Critical care demand person-days
# * Deaths

# %% [markdown]
# ## 2. Unmitigated COVID-19 Epidemic Trajectory

# %% [markdown]
# Here we assume the epidemic spreads through the camp without any non-pharmaceutical intervention in place and the peak incidence (number of cases), the timing and the cumulative case counts are all presented by interquartile range values (25%-75% quantiles) and they respectively represent the optimistic and pessimistic estimates of the spread of the virus given the uncertainty in parameters estimated from epidemiological studies. In the simulations, we explore a range of reproduction numbers, pre-symptomatic duration, rate of recovery, rate of severe infections and death rates based on estimates in the European and Asian settings to nearly what is estimated from a high population density location like a cruise ship.

# %%
#best to add a percentage here
prevalence_table_all=prevalence_all_table(baseline,with_percentage=True,camp_name=camp_name);prevalence_table_all
# Out:
# <style  type="text/css" >
#     #T_2494a8d2_b4b2_11ea_acbc_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_2494a8d2_b4b2_11ea_acbc_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_2494a8d2_b4b2_11ea_acbc_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263" ><caption>Peak day and peak number for prevalences of different disease states of COVID19</caption><thead>    <tr>        <th class="col_heading level0 col0" >Outcome</th>        <th class="col_heading level0 col1" >Peak Day IQR</th>        <th class="col_heading level0 col2" >Peak Number IQR</th>        <th class="col_heading level0 col3" >Pecentage regard to total population</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row0_col0" class="data row0 col0" >Prevalence of Symptomatic Cases</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row0_col1" class="data row0 col1" >42-62</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row0_col2" class="data row0 col2" >659-1031</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row0_col3" class="data row0 col3" >       7.0%-      10.9%</td>
#             </tr>
#             <tr>
#                                 <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row1_col0" class="data row1 col0" >Hospitalisation Demand</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row1_col1" class="data row1 col1" >51-72</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row1_col2" class="data row1 col2" >12-20</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row1_col3" class="data row1 col3" >       0.1%-       0.2%</td>
#             </tr>
#             <tr>
#                                 <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row2_col0" class="data row2 col0" >Critical Care Demand</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row2_col1" class="data row2 col1" >60-81</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row2_col2" class="data row2 col2" >4-6</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row2_col3" class="data row2 col3" >       0.0%-       0.1%</td>
#             </tr>
#             <tr>
#                                 <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row3_col0" class="data row3 col0" >Prevalence of Deaths</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row3_col1" class="data row3 col1" >60-81</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row3_col2" class="data row3 col2" >0-0</td>
#                         <td id="T_2494a8d2_b4b2_11ea_acbc_acbc32839263row3_col3" class="data row3 col3" >       0.0%-       0.0%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The peak number of infections is likely to be in the thousands, easily overwhelming the care capacity of the normal clinics within the camp and this could occur one and a half month after the virus first appears in the camp. The prevalence of hospitalisation, critical condition and death estimated are low: the peak hospitalisation demand will be 12-20 a day and the death estimate is based on the fact the patients require critical care will receive appropriate treatment from the nearby hospitals. The prevalence of death could be as high as the peak critical care demand (4-6) if camp residents are denied treatment at the ICU facility in the nearby hospitals.

# %%
first_death_instance(baseline)
# Out:
# <style  type="text/css" >
#     #T_c51821c4_b4b4_11ea_b29b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_c51821c4_b4b4_11ea_b29b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_c51821c4_b4b4_11ea_b29b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_c51821c4_b4b4_11ea_b29b_acbc32839263" ><caption>Estimated first incidence of deaths in all simulations</caption><thead>    <tr>        <th class="col_heading level0 col0" >Outcome</th>        <th class="col_heading level0 col1" >Estimated Day</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c51821c4_b4b4_11ea_b29b_acbc32839263row0_col0" class="data row0 col0" >First incidence of death since the virus first arrives in the camp</td>
#                         <td id="T_c51821c4_b4b4_11ea_b29b_acbc32839263row0_col1" class="data row0 col1" >42-58</td>
#             </tr>
#     </tbody></table>

# %%
prevalence_table_age=prevalence_age_table(baseline);prevalence_table_age
# Out:
# <style  type="text/css" >
#     #T_cce62c48_b4b4_11ea_b29b_acbc32839263 th {
#           font-size: 15px;
#     }    #T_cce62c48_b4b4_11ea_b29b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_cce62c48_b4b4_11ea_b29b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_cce62c48_b4b4_11ea_b29b_acbc32839263" ><caption>Peak day and peak prevalences of different disease states of COVID19 breakdown by age</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Peak Day, IQR</th>        <th class="col_heading level0 col1" >Peak Number, IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level0_row0" class="row_heading level0 row0" rowspan=9>Incident Cases</th>
#                         <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row0" class="row_heading level1 row0" >all ages</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row0_col0" class="data row0 col0" >42-62</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row0_col1" class="data row0 col1" >659-1031</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row1" class="row_heading level1 row1" ><9 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row1_col0" class="data row1 col0" >43-63</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row1_col1" class="data row1 col1" >266-419</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row2" class="row_heading level1 row2" >10-19 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row2_col0" class="data row2 col0" >39-59</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row2_col1" class="data row2 col1" >294-445</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row3" class="row_heading level1 row3" >20-29 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row3_col0" class="data row3 col0" >46-67</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row3_col1" class="data row3 col1" >55-97</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row4" class="row_heading level1 row4" >30-39 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row4_col0" class="data row4 col0" >47-68</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row4_col1" class="data row4 col1" >35-63</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row5" class="row_heading level1 row5" >40-49 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row5_col0" class="data row5 col0" >47-68</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row5_col1" class="data row5 col1" >20-36</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row6" class="row_heading level1 row6" >50-59 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row6_col0" class="data row6 col0" >47-68</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row6_col1" class="data row6 col1" >9-17</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row7" class="row_heading level1 row7" >60-69 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row7_col0" class="data row7 col0" >48-70</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row7_col1" class="data row7 col1" >2-3</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row8" class="row_heading level1 row8" >70+ years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row8_col0" class="data row8 col0" >48-69</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row8_col1" class="data row8 col1" >1-1</td>
#             </tr>
#             <tr>
#                         <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level0_row9" class="row_heading level0 row9" rowspan=9>Hospital Demand</th>
#                         <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row9" class="row_heading level1 row9" >all ages</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row9_col0" class="data row9 col0" >51-72</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row9_col1" class="data row9 col1" >12-20</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row10" class="row_heading level1 row10" ><9 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row10_col0" class="data row10 col0" >49-70</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row10_col1" class="data row10 col1" >3-4</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row11" class="row_heading level1 row11" >10-19 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row11_col0" class="data row11 col0" >45-66</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row11_col1" class="data row11 col1" >3-5</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row12" class="row_heading level1 row12" >20-29 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row12_col0" class="data row12 col0" >53-74</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row12_col1" class="data row12 col1" >1-1</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row13" class="row_heading level1 row13" >30-39 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row13_col0" class="data row13 col0" >54-76</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row13_col1" class="data row13 col1" >1-2</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row14" class="row_heading level1 row14" >40-49 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row14_col0" class="data row14 col0" >54-76</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row14_col1" class="data row14 col1" >2-3</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row15" class="row_heading level1 row15" >50-59 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row15_col0" class="data row15 col0" >54-76</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row15_col1" class="data row15 col1" >2-4</td>
#             </tr>
#             <tr>
#                                 <th id="T_cce62c48_b4b4_11ea_b29b_acbc32839263level1_row16" class="row_heading level1 row16" >60-69 years</th>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row16_col0" class="data row16 col0" >55-77</td>
#                         <td id="T_cce62c48_b4b4_11ea_b29b_acbc32839263row16_col1" class="data row16 col1" >1-2</td>
#             </tr>
#             <tr>

# %% [markdown]
# The age breakdown for the peak incidence shows that during the peak infection, residents aged below the age of 40 will comprise of more than 98% of the symptomatic infections while about 40% of the people require hospitalisation on any given day will be above the age of 40. Noted that these estimates all project peak of the epidemic to be a month and a half since the first case of COVID19 in the highly infectious scenario, giving local residents a period of time to react and try to curb the spread of the virus. Noted that the virus could be present in the camp without being noticed until the first death occurrence which is projected to be one month after the virus arrives at the camp in the fastest case.

# %%
comulative_table_all=cumulative_all_table(baseline,camp_name);comulative_table_all
# Out:
# <style  type="text/css" >
#     #T_8f259dc8_b4b2_11ea_b29b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_8f259dc8_b4b2_11ea_b29b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_8f259dc8_b4b2_11ea_b29b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263" ><caption>Cumulative case counts of different disease states of COVID19</caption><thead>    <tr>        <th class="col_heading level0 col0" >Totals</th>        <th class="col_heading level0 col1" >Counts</th>        <th class="col_heading level0 col2" >Percentage of total population</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row0_col0" class="data row0 col0" >Symptomatic Cases</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row0_col1" class="data row0 col1" >2577-2967</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row0_col2" class="data row0 col2" >27.22%-31.35%</td>
#             </tr>
#             <tr>
#                                 <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row1_col0" class="data row1 col0" >Hospital Person-Days</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row1_col1" class="data row1 col1" >525-695</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row1_col2" class="data row1 col2" >0.69%-0.92%</td>
#             </tr>
#             <tr>
#                                 <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row2_col0" class="data row2 col0" >Critical Person-days</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row2_col1" class="data row2 col1" >201-257</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row2_col2" class="data row2 col2" >0.21%-0.27%</td>
#             </tr>
#             <tr>
#                                 <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row3_col0" class="data row3 col0" >Deaths</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row3_col1" class="data row3 col1" >15-19</td>
#                         <td id="T_8f259dc8_b4b2_11ea_b29b_acbc32839263row3_col2" class="data row3 col2" >0.16%-0.20%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Looking at the cumulative counts in the course of the simulation spanning 200 days since the arrival of the virus, more than one-fourth of the camp residents are expected to be symptomatically infected by the virus and the total hospital person-days will be over 500 person-days which is around 1% of the population within the camp. This can be translated into projected medical costs or time required from medical staff if the medical cost and time taken is known for treating one patient for a day.

# %%
count_table_age=cumulative_age_table(baseline);count_table_age
# Out:
# <style  type="text/css" >
#     #T_7c3c3f20_b4b5_11ea_b29b_acbc32839263 th {
#           font-size: 15px;
#     }    #T_7c3c3f20_b4b5_11ea_b29b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_7c3c3f20_b4b5_11ea_b29b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263" ><caption>Cumulative case counts of different disease states of COVID19 breakdown by age</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >First month</th>        <th class="col_heading level0 col1" >First three months</th>        <th class="col_heading level0 col2" >First six months</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level0_row0" class="row_heading level0 row0" rowspan=9>Symptomatic Cases</th>
#                         <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row0" class="row_heading level1 row0" >all ages</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row0_col0" class="data row0 col0" >66-570</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row0_col1" class="data row0 col1" >2499-2962</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row0_col2" class="data row0 col2" >2576-2967</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row1" class="row_heading level1 row1" ><9 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row1_col0" class="data row1 col0" >30-259</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row1_col1" class="data row1 col1" >1189-1323</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row1_col2" class="data row1 col2" >1217-1324</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row2" class="row_heading level1 row2" >10-19 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row2_col0" class="data row2 col0" >26-211</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row2_col1" class="data row2 col1" >618-650</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row2_col2" class="data row2 col2" >624-651</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row3" class="row_heading level1 row3" >20-29 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row3_col0" class="data row3 col0" >4-36</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row3_col1" class="data row3 col1" >228-313</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row3_col2" class="data row3 col2" >241-314</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row4" class="row_heading level1 row4" >30-39 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row4_col0" class="data row4 col0" >3-25</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row4_col1" class="data row4 col1" >180-256</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row4_col2" class="data row4 col2" >192-257</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row5" class="row_heading level1 row5" >40-49 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row5_col0" class="data row5 col0" >2-21</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row5_col1" class="data row5 col1" >147-215</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row5_col2" class="data row5 col2" >156-216</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row6" class="row_heading level1 row6" >50-59 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row6_col0" class="data row6 col0" >1-13</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row6_col1" class="data row6 col1" >93-137</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row6_col2" class="data row6 col2" >99-137</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row7" class="row_heading level1 row7" >60-69 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row7_col0" class="data row7 col0" >0-4</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row7_col1" class="data row7 col1" >32-50</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row7_col2" class="data row7 col2" >35-50</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row8" class="row_heading level1 row8" >70+ years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row8_col0" class="data row8 col0" >0-2</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row8_col1" class="data row8 col1" >12-19</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row8_col2" class="data row8 col2" >13-19</td>
#             </tr>
#             <tr>
#                         <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level0_row9" class="row_heading level0 row9" rowspan=9>Hospital Person-Days</th>
#                         <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row9" class="row_heading level1 row9" >all ages</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row9_col0" class="data row9 col0" >2-13</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row9_col1" class="data row9 col1" >407-650</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row9_col2" class="data row9 col2" >525-695</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row10" class="row_heading level1 row10" ><9 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row10_col0" class="data row10 col0" >0-3</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row10_col1" class="data row10 col1" >92-129</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row10_col2" class="data row10 col2" >112-137</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row11" class="row_heading level1 row11" >10-19 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row11_col0" class="data row11 col0" >1-5</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row11_col1" class="data row11 col1" >107-139</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row11_col2" class="data row11 col2" >120-146</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263level1_row12" class="row_heading level1 row12" >20-29 years</th>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row12_col0" class="data row12 col0" >0-1</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row12_col1" class="data row12 col1" >25-43</td>
#                         <td id="T_7c3c3f20_b4b5_11ea_b29b_acbc32839263row12_col2" class="data row12 col2" >34-47</td>
#             </tr>
#             <tr>
#                                 <th id="T_7c

# %% [markdown]
# The cumulative incidence table for different disease status paints a similar picture compared to the peak prevalence table where younger residents account for most of the symptomatic infections but the older residents account for most of the hospitalisation/critical/death incidences. Most of the cases come from 2-3 months while in the first months the number of symptomatically infected people could range from 60 to 500.

# %%
plot_all(baseline)

# %%
plot_by_age_all(baseline)

# %% [markdown]
# Visually comparing different age groups in different disease status, residents of age 50-59 are hit the hardest in terms of hopitatlisation, critical and deaths with residents of age 40-49 second in line. In terms of symptomatic infection, residents of age 20-29 are affected the worst with residents of age 10-19 second in line.

# %% [markdown]
# ## 2. Invervention scenarios

# %% [markdown]
# ### 2.1 Single intervention scenarios

# %% [markdown]
# We assumed these interventions are applied at the camp-wide level and they are assumed to have full coverage starting from a certain day that is specified by the simulation and there are five interventions that are currently implemented.
#
# * Improved handwashing, masks for everyone, general social distancing and other interventions that aim to reduce person-to-person transmission probabilities that are not location-specific belongs to this first group of intervention. Here we set the effectiveness of the intervention as anther variable: 10% reduction in transmission rate: somewhat effective, 20% reduction: effective, 30% reduction: very effective.
# * Isolate symptomatically infected residents: here we assume the residents are isolated in a separate isolation centre off-site, therefore, the transmission between infected residents in these centres with anyone outside is cut off (we haven't factored in the case where detecting these individuals can have a period of delay and the isolation centres that are currently in place are inside the camp where people still share water points and toilets.)
# * Move high-risk residents (age>60) offsite. Here we control the time periods that this is happening and the number of high-risk people being moved off-site each day during that time period. Total residents moved offsite is 250.
# * Shielding: Instead being moved offsite, the high-risk residents are housed in a green zone in the camp facility and they self-manage the sector while the entry into the green zone is limited so the contact between older residents and younger residents are reduced.

# %% [markdown]
# Three high-level insights:
# 1. Reducing individual-level transmission via social distancing, masks and regular handwashing can result in decreasing up to 20% of all cases in the most optimistic scenario. Prioritising a longer, sustained program is arguably more important than prioritising a short-lived stringent program as it demonstrates that if a program is only effective for 1-2 months, it has minimal effect on curbing the cumulative number of the infectious cases other than delaying the peak infections by a few days.
# 2. Removing high-risk residents offsite early will not impact the total number of people infected but will reduce the hospitalisation need, critical care need and death incidences onsite by 10%.
# 3. Isolating symptomatically infected people until they are recovered (still need more investigation and tweaking) currently suggests that the capacity of the isolation centre is less important than having a long and rigorous surveillance program (one such program aims to isolate 10 people per day) (need further tweaking to see how much impact this have on the total number of people infected)

# %% [markdown]
# The plot below shows the top 5 single intervention scenarios for reducing peak numbers in each state in descending order:
# * Committing to the long-term 'isolation the symptomatically infected people' can help curb the epidemic in all categories and potentially coupled with contact tracing to encourage self-isolation of asymptomatically infected people who are in touch with them can further drive the numbers down.
# * Committing to the long-term social distancing/mask/handwashing can help curb the virus tremendously but we need to benchmark the effectiveness of these approaches (possibly by motion tracking or random surveys)
# * Removing high-risk residents have a big impact on driving on the death numbers and we have yet to model the effect of removing unaccompanied children off the island.

# %%
plot_one_intervention_vertical_interactive(plot_one_intervention_vertical,camp_name)
# Out:
# interactive(children=(Select(description='Category:', options=('Infected (symptomatic)', 'Hospitalised', 'Crit…

# %% [markdown]
# The tables below from each intervention show the % net reduction to cases, deaths, and hospitalised person­days in these scenarios, 200 days after initial introduction in Moria.

# %% [markdown]
# ### 2.1.1 Improved personal hygiene (social distancing/PPE/regular handwashing)

# %% [markdown]
# We are exploring two factors here:
# * How effective will the intervention measures have to be the reduce the spread of the virus?
# * How long will such measures have to be in place for them to be effective?

# %%
# folder_path=os.path.join('model_outcomes',camp_name,'one_intervention')
# intervention_dict=load_intervention_dict(camp_name)
# selectedInterventions=load_interventions(folder_path,camp_name,prefix='hygiene0.7')
# selectedInterventions={intervention_dict[k]: v for k, v in sorted(selectedInterventions.items(), key=lambda item: int(item[0].split('-')[1]))}

# %%
# caption='Reduction in cumulative incidences of the same hygiene measures but with different timings'

# %%
# comparisondf,percentagedf=effectiveness_cum_table(baseline,selectedInterventions,camp_name)

# %%
# style_table(percentagedf,caption)
# Out:
# <style  type="text/css" >
#     #T_039d54c4_b67b_11ea_ad0b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_039d54c4_b67b_11ea_ad0b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_039d54c4_b67b_11ea_ad0b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_039d54c4_b67b_11ea_ad0b_acbc32839263" ><caption>Reduction in cumulative incidences of the same hygiene measures but with different timings</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >baseline</th>        <th class="col_heading level0 col1" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 30</th>        <th class="col_heading level0 col2" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 60</th>        <th class="col_heading level0 col3" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 90</th>        <th class="col_heading level0 col4" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 180</th>    </tr>    <tr>        <th class="index_name level0" >Total percentage of the population</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_039d54c4_b67b_11ea_ad0b_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row0_col0" class="data row0 col0" >27.22%-31.35%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row0_col1" class="data row0 col1" >27.22%-31.31%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row0_col2" class="data row0 col2" >26.79%-29.96%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row0_col3" class="data row0 col3" >24.91%-27.87%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row0_col4" class="data row0 col4" >20.99%-27.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_039d54c4_b67b_11ea_ad0b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row1_col0" class="data row1 col0" >0.69%-0.92%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row1_col1" class="data row1 col1" >0.69%-0.92%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row1_col2" class="data row1 col2" >0.67%-0.86%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row1_col3" class="data row1 col3" >0.61%-0.77%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row1_col4" class="data row1 col4" >0.50%-0.73%</td>
#             </tr>
#             <tr>
#                         <th id="T_039d54c4_b67b_11ea_ad0b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row2_col0" class="data row2 col0" >0.21%-0.27%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row2_col1" class="data row2 col1" >0.21%-0.27%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row2_col2" class="data row2 col2" >0.20%-0.25%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row2_col3" class="data row2 col3" >0.19%-0.23%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row2_col4" class="data row2 col4" >0.15%-0.22%</td>
#             </tr>
#             <tr>
#                         <th id="T_039d54c4_b67b_11ea_ad0b_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row3_col0" class="data row3 col0" >0.16%-0.20%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row3_col1" class="data row3 col1" >0.16%-0.20%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row3_col2" class="data row3 col2" >0.16%-0.19%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row3_col3" class="data row3 col3" >0.14%-0.17%</td>
#                         <td id="T_039d54c4_b67b_11ea_ad0b_acbc32839263row3_col4" class="data row3 col4" >0.12%-0.16%</td>
#             </tr>
#     </tbody></table>

# %%
#NEW FEATURE
#produce a new table that looks how what is the percentage of population comparing each compartment to the baseline
#to not duplicate too much code - we should modify the existing comparison code to produce two tables

# %%
effectiveness_cum_table_hygiene(baseline,camp_name,timing=True)
# Out:
# <style  type="text/css" >
#     #T_f6854e2a_b4e2_11ea_9c6c_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_f6854e2a_b4e2_11ea_9c6c_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_f6854e2a_b4e2_11ea_9c6c_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263" ><caption>Reduction in cumulative incidences of the same hygiene measures but with different timings</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 30</th>        <th class="col_heading level0 col1" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 60</th>        <th class="col_heading level0 col2" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 90</th>        <th class="col_heading level0 col3" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 180</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row0_col0" class="data row0 col0" >0%~0%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row0_col1" class="data row0 col1" >2%~4%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row0_col2" class="data row0 col2" >8%~11%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row0_col3" class="data row0 col3" >13%~23%</td>
#             </tr>
#             <tr>
#                         <th id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row1_col0" class="data row1 col0" >0%~0%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row1_col1" class="data row1 col1" >3%~7%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row1_col2" class="data row1 col2" >12%~16%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row1_col3" class="data row1 col3" >20%~28%</td>
#             </tr>
#             <tr>
#                         <th id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row2_col0" class="data row2 col0" >0%~1%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row2_col1" class="data row2 col1" >4%~7%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row2_col2" class="data row2 col2" >12%~16%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row2_col3" class="data row2 col3" >20%~28%</td>
#             </tr>
#             <tr>
#                         <th id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row3_col0" class="data row3 col0" >0%~0%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row3_col1" class="data row3 col1" >0%~5%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row3_col2" class="data row3 col2" >7%~16%</td>
#                         <td id="T_f6854e2a_b4e2_11ea_9c6c_acbc32839263row3_col3" class="data row3 col3" >21%~27%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Here we explore how the duration of implementing such measures could have an impact on the number of cases reduced and lives saved. Clearly the longer personal hygiene measures are in place the better. Interesting to note that, if these improving hygiene measures are only implemented during the nascent period of the virus (first month) it won't have an impact on the spread of the virus at all. 2 months of applying the measures will yield a minimal reduction in accumulative numbers while implementing for 3+ months can really start yielding promising results in curbing the spread of the virus.

# %%
effectiveness_peak_table_hygiene(baseline,camp_name,timing=True)
# Out:
# <style  type="text/css" >
#     #T_def797e0_b4ec_11ea_9c09_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_def797e0_b4ec_11ea_9c09_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_def797e0_b4ec_11ea_9c09_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_def797e0_b4ec_11ea_9c09_acbc32839263" ><caption>Delay and reduction in peak prevalence for same program with different lengths of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 30</th>        <th class="col_heading level0 col2" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 60</th>        <th class="col_heading level0 col4" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 90</th>        <th class="col_heading level0 col6" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 180</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col6" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col7" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_def797e0_b4ec_11ea_9c09_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col0" class="data row0 col0" >10~13 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col1" class="data row0 col1" >1%~1%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col2" class="data row0 col2" >18~26 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col3" class="data row0 col3" >13%~21%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col4" class="data row0 col4" >17~41 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col5" class="data row0 col5" >32%~33%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col6" class="data row0 col6" >17~32 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row0_col7" class="data row0 col7" >33%~48%</td>
#             </tr>
#             <tr>
#                         <th id="T_def797e0_b4ec_11ea_9c09_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col0" class="data row1 col0" >11~12 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col1" class="data row1 col1" >0%~5%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col2" class="data row1 col2" >21~26 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col3" class="data row1 col3" >0%~25%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col4" class="data row1 col4" >18~40 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col5" class="data row1 col5" >25%~35%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col6" class="data row1 col6" >17~33 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row1_col7" class="data row1 col7" >35%~42%</td>
#             </tr>
#             <tr>
#                         <th id="T_def797e0_b4ec_11ea_9c09_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col0" class="data row2 col0" >10~12 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col1" class="data row2 col1" >0%~0%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col2" class="data row2 col2" >20~25 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col3" class="data row2 col3" >0%~17%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col4" class="data row2 col4" >17~40 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col5" class="data row2 col5" >25%~33%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col6" class="data row2 col6" >17~33 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row2_col7" class="data row2 col7" >33%~50%</td>
#             </tr>
#             <tr>
#                         <th id="T_def797e0_b4ec_11ea_9c09_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col0" class="data row3 col0" >11~13 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col1" class="data row3 col1" >100%~100%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col2" class="data row3 col2" >21~26 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col3" class="data row3 col3" >100%~100%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col4" class="data row3 col4" >17~41 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col5" class="data row3 col5" >100%~100%</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col6" class="data row3 col6" >17~33 days</td>
#                         <td id="T_def797e0_b4ec_11ea_9c09_acbc32839263row3_col7" class="data row3 col7" >100%~100%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Here we explore how such measures can have an impact on the peak incidences and the days in which they occur. Note that a short-lived measure can delay the onset of the epidemic by 10 days while a longer-lasting control measure can delay the epidemic by more than 3 weeks while reducing the peak incidences of symptomatic infections by a third.

# %%
plot_hygiene_intervention_horizontal(baseline,camp_name)

# %%
effectiveness_cum_table_hygiene(baseline,camp_name,timing=False)
# Out:
# <style  type="text/css" >
#     #T_28ef0fa4_b67d_11ea_92fe_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_28ef0fa4_b67d_11ea_92fe_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_28ef0fa4_b67d_11ea_92fe_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263" ><caption>Reduction in cumulative incidences of different levels of hygiene measures in the same time frame</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reduce transmission by 10% by social distancing/mask/handwashing from day 0 to day 180</th>        <th class="col_heading level0 col1" >reduce transmission by 20% by social distancing/mask/handwashing from day 0 to day 180</th>        <th class="col_heading level0 col2" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 180</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row0_col0" class="data row0 col0" >3%~6%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row0_col1" class="data row0 col1" >8%~13%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row0_col2" class="data row0 col2" >13%~23%</td>
#             </tr>
#             <tr>
#                         <th id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row1_col0" class="data row1 col0" >6%~8%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row1_col1" class="data row1 col1" >12%~17%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row1_col2" class="data row1 col2" >20%~28%</td>
#             </tr>
#             <tr>
#                         <th id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row2_col0" class="data row2 col0" >6%~7%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row2_col1" class="data row2 col1" >12%~17%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row2_col2" class="data row2 col2" >20%~28%</td>
#             </tr>
#             <tr>
#                         <th id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row3_col0" class="data row3 col0" >5%~7%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row3_col1" class="data row3 col1" >11%~13%</td>
#                         <td id="T_28ef0fa4_b67d_11ea_92fe_acbc32839263row3_col2" class="data row3 col2" >21%~27%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Here we explore how strict these hygiene measures should be and quite rightly so, the better you can do it, the better the results in minimising the impact of the virus. (Further points - how large should the program cover in the total population and what if some people conform and other people disobey social distancing/masks/hand washing)

# %%
effectiveness_peak_table_hygiene(baseline,camp_name,timing=False)
# Out:
# <style  type="text/css" >
#     #T_363e5dfe_b67d_11ea_92fe_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_363e5dfe_b67d_11ea_92fe_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_363e5dfe_b67d_11ea_92fe_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_363e5dfe_b67d_11ea_92fe_acbc32839263" ><caption>Delay and reduction in peak prevalence for different programs with the same length of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>reduce transmission by 10% by social distancing/mask/handwashing from day 0 to day 180</th>        <th class="col_heading level0 col2" colspan=2>reduce transmission by 20% by social distancing/mask/handwashing from day 0 to day 180</th>        <th class="col_heading level0 col4" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 180</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_363e5dfe_b67d_11ea_92fe_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row0_col0" class="data row0 col0" >4~7 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row0_col1" class="data row0 col1" >10%~14%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row0_col2" class="data row0 col2" >9~18 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row0_col3" class="data row0 col3" >20%~31%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row0_col4" class="data row0 col4" >17~32 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row0_col5" class="data row0 col5" >33%~48%</td>
#             </tr>
#             <tr>
#                         <th id="T_363e5dfe_b67d_11ea_92fe_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row1_col0" class="data row1 col0" >4~7 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row1_col1" class="data row1 col1" >8%~10%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row1_col2" class="data row1 col2" >10~17 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row1_col3" class="data row1 col3" >20%~25%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row1_col4" class="data row1 col4" >17~33 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row1_col5" class="data row1 col5" >35%~42%</td>
#             </tr>
#             <tr>
#                         <th id="T_363e5dfe_b67d_11ea_92fe_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row2_col0" class="data row2 col0" >4~7 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row2_col1" class="data row2 col1" >0%~17%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row2_col2" class="data row2 col2" >9~17 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row2_col3" class="data row2 col3" >17%~25%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row2_col4" class="data row2 col4" >17~33 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row2_col5" class="data row2 col5" >33%~50%</td>
#             </tr>
#             <tr>
#                         <th id="T_363e5dfe_b67d_11ea_92fe_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row3_col0" class="data row3 col0" >4~7 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row3_col1" class="data row3 col1" >100%~100%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row3_col2" class="data row3 col2" >10~18 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row3_col3" class="data row3 col3" >100%~100%</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row3_col4" class="data row3 col4" >17~33 days</td>
#                         <td id="T_363e5dfe_b67d_11ea_92fe_acbc32839263row3_col5" class="data row3 col5" >100%~100%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# A stricter measure can delay the onset of the epidemic by more than two weeks contrasting with a less strict measure delating onset by only less than a week.

# %%
plot_hygiene_intervention_horizontal(baseline,camp_name,timing=False)

# %%
plot_onetype_intervention_vertical('hygiene',camp_name)

# %% [markdown]
# Comparison among the plots (the most effective at the top) shows that prioritising a long-term, sustainable program is more important than having an effective yet short-lived one. There are no quick fixes here!

# %% [markdown]
# ### 2.1.2 Move high risk residents off-site

# %%
#To start changing the analysis here

# %% [markdown]
# Here we assume that there are about 500 residents within the camp who can be classified as high risk (>age 60) so they should go into self-shielding or be moved off-site. We explore removing these residents at a different rate and how that can have an impact on the epidemic.

# %%
effectiveness_cum_table_onetype(baseline,'highrisk',camp_name,caption='Effect of removing high risk residents from the camp on cumulative cases of incidence',display=False)
# Out:
# <style  type="text/css" >
#     #T_fb0a09de_b4ee_11ea_a944_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_fb0a09de_b4ee_11ea_a944_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_fb0a09de_b4ee_11ea_a944_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_fb0a09de_b4ee_11ea_a944_acbc32839263" ><caption>Effect of removing high risk residents from the camp on cumulative cases of incidence</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >remove 10 high-risk residents from day 0 to day 25</th>        <th class="col_heading level0 col1" >remove 50 high-risk residents from day 0 to day 5</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb0a09de_b4ee_11ea_a944_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row0_col0" class="data row0 col0" >-5%~-4%</td>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row0_col1" class="data row0 col1" >-5%~-4%</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0a09de_b4ee_11ea_a944_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row1_col0" class="data row1 col0" >11%~12%</td>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row1_col1" class="data row1 col1" >10%~12%</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0a09de_b4ee_11ea_a944_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row2_col0" class="data row2 col0" >11%~13%</td>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row2_col1" class="data row2 col1" >11%~12%</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0a09de_b4ee_11ea_a944_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row3_col0" class="data row3 col0" >7%~11%</td>
#                         <td id="T_fb0a09de_b4ee_11ea_a944_acbc32839263row3_col1" class="data row3 col1" >7%~11%</td>
#             </tr>
#     </tbody></table>

# %%
effectiveness_peak_table_onetype(baseline,'highrisk',camp_name)
# Out:
# <style  type="text/css" >
#     #T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263" ><caption>Placeholder</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>remove 50 high-risk residents from day 0 to day 5</th>        <th class="col_heading level0 col2" colspan=2>remove 10 high-risk residents from day 0 to day 25</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row0_col0" class="data row0 col0" >0~0 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row0_col2" class="data row0 col2" >0~0 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row0_col3" class="data row0 col3" >0%~0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row1_col0" class="data row1 col0" >-1~-1 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row1_col1" class="data row1 col1" >8%~15%</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row1_col2" class="data row1 col2" >-1~-1 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row1_col3" class="data row1 col3" >8%~15%</td>
#             </tr>
#             <tr>
#                         <th id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row2_col0" class="data row2 col0" >-1~-1 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row2_col1" class="data row2 col1" >0%~17%</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row2_col2" class="data row2 col2" >-1~-1 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row2_col3" class="data row2 col3" >0%~17%</td>
#             </tr>
#             <tr>
#                         <th id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row3_col0" class="data row3 col0" >0~0 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row3_col1" class="data row3 col1" >100%~100%</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row3_col2" class="data row3 col2" >0~0 days</td>
#                         <td id="T_c9cdf76c_b4ef_11ea_9ec3_acbc32839263row3_col3" class="data row3 col3" >100%~100%</td>
#             </tr>
#     </tbody></table>

# %%
plot_onetype_intervention_horizontal(baseline,'highrisk',camp_name,'Deaths')

# %% [markdown]
# Removing high risk residents (age>60) offsite early will not impact the total number of people infected but will reduce the hospitalisation need, critical care need and death incidences onsite by 5-10%. The timing of it does not matter as long as the residents are removed before the peak of the epidemic.

# %% [markdown]
# ### 2.1.3 Isolate sympotomatically infected residents

# %% [markdown]
# Here we explore this intervention along two dimensions:
# * the capacity at which we can make sure the infected residents are isolated (6%,18%,36%,45%)
# * the detection/isolation rate at which such intervention is carried out (20,50 people per day)

# %%
cumulative_iso_table(camp_name,False)
# Out:
# <style  type="text/css" >
#     #T_84d7e30e_b5a1_11ea_aa8d_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_84d7e30e_b5a1_11ea_aa8d_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_84d7e30e_b5a1_11ea_aa8d_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263" ><caption>Cumulative number of Quarantine Person-Days for different isolation strategies COVID19</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Qurantined Person-Days</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263level0_row0" class="row_heading level0 row0" >isolate symptomatically infected people at 50 people per day for 90 days</th>
#                         <td id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263row0_col0" class="data row0 col0" >46-587</td>
#             </tr>
#             <tr>
#                         <th id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263level0_row1" class="row_heading level0 row1" >isolate symptomatically infected people at 20 people per day for 180 days</th>
#                         <td id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263row1_col0" class="data row1 col0" >40-4793</td>
#             </tr>
#             <tr>
#                         <th id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263level0_row2" class="row_heading level0 row2" >isolate symptomatically infected people at 20 people per day for 90 days</th>
#                         <td id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263row2_col0" class="data row2 col0" >33-579</td>
#             </tr>
#             <tr>
#                         <th id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263level0_row3" class="row_heading level0 row3" >isolate symptomatically infected people at 50 people per day for 30 days</th>
#                         <td id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263row3_col0" class="data row3 col0" >19-46</td>
#             </tr>
#             <tr>
#                         <th id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263level0_row4" class="row_heading level0 row4" >isolate symptomatically infected people at 20 people per day for 30 days</th>
#                         <td id="T_84d7e30e_b5a1_11ea_aa8d_acbc32839263row4_col0" class="data row4 col0" >18-46</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The table above shows that the isolation intervention can be quite a resource intensive operation

# %%
effectiveness_cum_table_iso(baseline,camp_name)
# Out:
# <style  type="text/css" >
#     #T_a4637e58_b66a_11ea_941e_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_a4637e58_b66a_11ea_941e_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_a4637e58_b66a_11ea_941e_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_a4637e58_b66a_11ea_941e_acbc32839263" ><caption>Effectiveness of the same isolation policy but with different lengths of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >isolate symptomatically infected people at 20 people per day for 30 days</th>        <th class="col_heading level0 col1" >isolate symptomatically infected people at 20 people per day for 90 days</th>        <th class="col_heading level0 col2" >isolate symptomatically infected people at 20 people per day for 180 days</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4637e58_b66a_11ea_941e_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row0_col0" class="data row0 col0" >0%~0%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row0_col1" class="data row0 col1" >1%~2%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row0_col2" class="data row0 col2" >53%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_a4637e58_b66a_11ea_941e_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row1_col0" class="data row1 col0" >0%~0%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row1_col1" class="data row1 col1" >3%~16%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row1_col2" class="data row1 col2" >79%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_a4637e58_b66a_11ea_941e_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row2_col0" class="data row2 col0" >1%~2%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row2_col1" class="data row2 col1" >5%~25%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row2_col2" class="data row2 col2" >82%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_a4637e58_b66a_11ea_941e_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row3_col0" class="data row3 col0" >0%~0%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row3_col1" class="data row3 col1" >5%~27%</td>
#                         <td id="T_a4637e58_b66a_11ea_941e_acbc32839263row3_col2" class="data row3 col2" >84%~100%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Due to the low infectiou dynamics assumed by the model, if a long and successful program is carried out to isolate 20 symptomatically infected people per day for the six months since the virus arrive in the camp then it can reduce the total infections by 50-100 percent. (If the isolation measures are lifted and the virus is still at large in the camp, you could still see a spike in numbers with roughly the same number of people eventually infected.)

# %%
effectiveness_peak_table_iso(baseline,camp_name)
# Out:
# <style  type="text/css" >
#     #T_13ba61d6_b66b_11ea_8fea_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_13ba61d6_b66b_11ea_8fea_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_13ba61d6_b66b_11ea_8fea_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_13ba61d6_b66b_11ea_8fea_acbc32839263" ><caption>Delay and reduction in peak prevalence for same program with different lengths of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>isolate symptomatically infected people at 20 people per day for 30 days</th>        <th class="col_heading level0 col2" colspan=2>isolate symptomatically infected people at 20 people per day for 90 days</th>        <th class="col_heading level0 col4" colspan=2>isolate symptomatically infected people at 20 people per day for 180 days</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13ba61d6_b66b_11ea_8fea_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row0_col0" class="data row0 col0" >26~35 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row0_col2" class="data row0 col2" >75~97 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row0_col3" class="data row0 col3" >5%~7%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row0_col4" class="data row0 col4" >-42~138 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row0_col5" class="data row0 col5" >60%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_13ba61d6_b66b_11ea_8fea_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row1_col0" class="data row1 col0" >27~35 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row1_col1" class="data row1 col1" >0%~0%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row1_col2" class="data row1 col2" >76~97 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row1_col3" class="data row1 col3" >0%~10%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row1_col4" class="data row1 col4" >-41~128 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row1_col5" class="data row1 col5" >75%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_13ba61d6_b66b_11ea_8fea_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row2_col0" class="data row2 col0" >25~35 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row2_col1" class="data row2 col1" >0%~0%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row2_col2" class="data row2 col2" >75~97 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row2_col3" class="data row2 col3" >0%~0%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row2_col4" class="data row2 col4" >-36~119 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row2_col5" class="data row2 col5" >83%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_13ba61d6_b66b_11ea_8fea_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row3_col0" class="data row3 col0" >26~35 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row3_col1" class="data row3 col1" >100%~100%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row3_col2" class="data row3 col2" >76~97 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row3_col3" class="data row3 col3" >100%~100%</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row3_col4" class="data row3 col4" >-36~119 days</td>
#                         <td id="T_13ba61d6_b66b_11ea_8fea_acbc32839263row3_col5" class="data row3 col5" >100%~100%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# A successful program can delay the peak of epidemic by more than 1-4 months time, buying time for other measures to take place more effectively.

# %%
plot_iso_intervention_horizontal(baseline,camp_name)

# %%
plot_iso_intervention_horizontal(baseline,camp_name,column='Quarantined')

# %%
effectiveness_cum_table_iso(baseline,camp_name,timing=False)
# Out:
# <style  type="text/css" >
#     #T_33b428ce_b674_11ea_951a_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_33b428ce_b674_11ea_951a_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_33b428ce_b674_11ea_951a_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_33b428ce_b674_11ea_951a_acbc32839263" ><caption>Effectiveness of the isolation policies with different lengths of implementation and different daily capacity</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >isolate symptomatically infected people at 50 people per day for 30 days</th>        <th class="col_heading level0 col1" >isolate symptomatically infected people at 20 people per day for 30 days</th>        <th class="col_heading level0 col2" >isolate symptomatically infected people at 50 people per day for 90 days</th>        <th class="col_heading level0 col3" >isolate symptomatically infected people at 20 people per day for 90 days</th>        <th class="col_heading level0 col4" >isolate symptomatically infected people at 20 people per day for 180 days</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33b428ce_b674_11ea_951a_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row0_col0" class="data row0 col0" >-2%~0%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row0_col2" class="data row0 col2" >0%~2%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row0_col3" class="data row0 col3" >1%~2%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row0_col4" class="data row0 col4" >53%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_33b428ce_b674_11ea_951a_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row1_col0" class="data row1 col0" >-4%~1%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row1_col1" class="data row1 col1" >0%~0%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row1_col2" class="data row1 col2" >6%~7%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row1_col3" class="data row1 col3" >3%~16%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row1_col4" class="data row1 col4" >79%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_33b428ce_b674_11ea_951a_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row2_col0" class="data row2 col0" >1%~2%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row2_col1" class="data row2 col1" >1%~2%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row2_col2" class="data row2 col2" >7%~19%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row2_col3" class="data row2 col3" >5%~25%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row2_col4" class="data row2 col4" >82%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_33b428ce_b674_11ea_951a_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row3_col0" class="data row3 col0" >-7%~0%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row3_col1" class="data row3 col1" >0%~0%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row3_col2" class="data row3 col2" >5%~13%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row3_col3" class="data row3 col3" >5%~27%</td>
#                         <td id="T_33b428ce_b674_11ea_951a_acbc32839263row3_col4" class="data row3 col4" >84%~100%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The table above really shows that a 6 month longer program is going to be much more successufl than a 3 month program assuming the efficacy of the intervention stays the same throughout.

# %%
effectiveness_peak_table_iso(baseline,camp_name,timing=False)
# Out:
# <style  type="text/css" >
#     #T_430fccec_b674_11ea_951a_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_430fccec_b674_11ea_951a_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_430fccec_b674_11ea_951a_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_430fccec_b674_11ea_951a_acbc32839263" ><caption>Delay and reduction in peak prevalence for different programs with different lengths of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>isolate symptomatically infected people at 50 people per day for 30 days</th>        <th class="col_heading level0 col2" colspan=2>isolate symptomatically infected people at 20 people per day for 30 days</th>        <th class="col_heading level0 col4" colspan=2>isolate symptomatically infected people at 50 people per day for 90 days</th>        <th class="col_heading level0 col6" colspan=2>isolate symptomatically infected people at 20 people per day for 90 days</th>        <th class="col_heading level0 col8" colspan=2>isolate symptomatically infected people at 20 people per day for 180 days</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col6" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col7" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col8" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col9" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_430fccec_b674_11ea_951a_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col0" class="data row0 col0" >26~32 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col1" class="data row0 col1" >1%~3%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col2" class="data row0 col2" >26~35 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col3" class="data row0 col3" >0%~0%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col4" class="data row0 col4" >77~95 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col5" class="data row0 col5" >9%~13%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col6" class="data row0 col6" >75~97 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col7" class="data row0 col7" >5%~7%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col8" class="data row0 col8" >-42~138 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row0_col9" class="data row0 col9" >60%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_430fccec_b674_11ea_951a_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col0" class="data row1 col0" >26~32 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col1" class="data row1 col1" >-8%~0%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col2" class="data row1 col2" >27~35 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col3" class="data row1 col3" >0%~0%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col4" class="data row1 col4" >77~96 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col5" class="data row1 col5" >-8%~10%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col6" class="data row1 col6" >76~97 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col7" class="data row1 col7" >0%~10%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col8" class="data row1 col8" >-41~128 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row1_col9" class="data row1 col9" >75%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_430fccec_b674_11ea_951a_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col0" class="data row2 col0" >25~32 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col1" class="data row2 col1" >0%~0%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col2" class="data row2 col2" >25~35 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col3" class="data row2 col3" >0%~0%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col4" class="data row2 col4" >76~95 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col5" class="data row2 col5" >0%~17%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col6" class="data row2 col6" >75~97 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col7" class="data row2 col7" >0%~0%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col8" class="data row2 col8" >-36~119 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row2_col9" class="data row2 col9" >83%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_430fccec_b674_11ea_951a_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col0" class="data row3 col0" >26~32 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col1" class="data row3 col1" >100%~100%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col2" class="data row3 col2" >26~35 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col3" class="data row3 col3" >100%~100%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col4" class="data row3 col4" >77~95 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col5" class="data row3 col5" >100%~100%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col6" class="data row3 col6" >76~97 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col7" class="data row3 col7" >100%~100%</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col8" class="data row3 col8" >-36~119 days</td>
#                         <td id="T_430fccec_b674_11ea_951a_acbc32839263row3_col9" class="data row3 col9" >100%~100%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# (The numbers in the last column are negative because in those cases the case numbers have been reduced to 0 so the corresponding peak day is before the peak of the epidemic in the baseline case)

# %%
plot_iso_intervention_horizontal(baseline,camp_name,timing=False)

# %%
plot_iso_intervention_horizontal(baseline,camp_name,column='Quarantined',timing=False)

# %% [markdown]
# The peak number of people being quarantined here is not big because we have reduced the total number of infections by a dramatic amount and we also assume that our isolation is both specific (identify all the symptomatic cases) and sensitive (only confirmed cases are identified).

# %%
plot_onetype_intervention_vertical('isolate50',camp_name,'Infected (symptomatic)')

# %%
plot_onetype_intervention_vertical('iso',camp_name,'Infected (symptomatic)')

# %% [markdown]
# Isolating symptomatic infected reduces the peak of the infection but it doen't nececarrily reduce the cumulative incidences of the total number of infections in the camp

# %% [markdown]
# ### 2.1.4 Shielding

# %% [markdown]
# NB: we are still experimenting with this feature as the in-group contacts are very high which end up exacerbating the epidemic.

# %%
effectiveness_cum_table_onetype(baseline,'shielding',camp_name)
# Out:
# <style  type="text/css" >
#     #T_d97e442e_b674_11ea_a46b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_d97e442e_b674_11ea_a46b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_d97e442e_b674_11ea_a46b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_d97e442e_b674_11ea_a46b_acbc32839263" ><caption>Placeholder</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shielding</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d97e442e_b674_11ea_a46b_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_d97e442e_b674_11ea_a46b_acbc32839263row0_col0" class="data row0 col0" >-24%~-14%</td>
#             </tr>
#             <tr>
#                         <th id="T_d97e442e_b674_11ea_a46b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_d97e442e_b674_11ea_a46b_acbc32839263row1_col0" class="data row1 col0" >-35%~-25%</td>
#             </tr>
#             <tr>
#                         <th id="T_d97e442e_b674_11ea_a46b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_d97e442e_b674_11ea_a46b_acbc32839263row2_col0" class="data row2 col0" >-21%~-6%</td>
#             </tr>
#             <tr>
#                         <th id="T_d97e442e_b674_11ea_a46b_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_d97e442e_b674_11ea_a46b_acbc32839263row3_col0" class="data row3 col0" >-47%~-32%</td>
#             </tr>
#     </tbody></table>

# %%
effectiveness_peak_table_shielding(baseline,camp_name)
# Out:
# <style  type="text/css" >
#     #T_df1af2f6_b674_11ea_a46b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_df1af2f6_b674_11ea_a46b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_df1af2f6_b674_11ea_a46b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_df1af2f6_b674_11ea_a46b_acbc32839263" ><caption>Placeholder</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>shielding</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df1af2f6_b674_11ea_a46b_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row0_col0" class="data row0 col0" >-27~-17 days</td>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row0_col1" class="data row0 col1" >-85%~-58%</td>
#             </tr>
#             <tr>
#                         <th id="T_df1af2f6_b674_11ea_a46b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row1_col0" class="data row1 col0" >-28~-17 days</td>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row1_col1" class="data row1 col1" >-92%~-50%</td>
#             </tr>
#             <tr>
#                         <th id="T_df1af2f6_b674_11ea_a46b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row2_col0" class="data row2 col0" >-33~-22 days</td>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row2_col1" class="data row2 col1" >-50%~0%</td>
#             </tr>
#             <tr>
#                         <th id="T_df1af2f6_b674_11ea_a46b_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row3_col0" class="data row3 col0" >-31~-22 days</td>
#                         <td id="T_df1af2f6_b674_11ea_a46b_acbc32839263row3_col1" class="data row3 col1" >-99999900%~-99999900%</td>
#             </tr>
#     </tbody></table>

# %%
plot_onetype_intervention_horizontal(baseline,'shielding',camp_name,'Deaths')

# %%
#distill each predominant feature from each intervention to design something that can have the best impact

# %%
plot_intervention_comparison_interactive(plot_intervention_comparison,baseline,camp_name)
# Out:
# VBox(children=(Label(value='Compare two different intervention strategies or compare a particular intervention…

# %% [markdown]
# ### 2.2 Onto designing multi-intervention strategies

# %% [markdown]
# A version of intervention could be:
#
# Invest in a prolonged programme in improving personal hygiene for the camp residents in the whole duration of the pandemic
#
# Let high-risk residents go into self-shielding when the virus is detected within the camp.
#
# Ask the residents who are infected to minimise their contacts and movement and make sure they have access to the necessary treatment (including ICU bed in the nearby hospital if need be)

# %%
effectiveness_cum_table_custom(baseline,camp_name,caption='Custom intervention pathway demonstration',display=False)
# Out:
# <style  type="text/css" >
#     #T_474155fc_bbeb_11ea_a41d_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_474155fc_bbeb_11ea_a41d_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_474155fc_bbeb_11ea_a41d_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_474155fc_bbeb_11ea_a41d_acbc32839263" ><caption>Custom intervention pathway demonstration</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Haman-al-Alil_hyg_0.7_[0, 180]_ICU_0.00063_rmSym_[0, 180]_0.00106_shield_False_rmRisky[0, 25]_0.00106</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_474155fc_bbeb_11ea_a41d_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_474155fc_bbeb_11ea_a41d_acbc32839263row0_col0" class="data row0 col0" >93%~94%</td>
#             </tr>
#             <tr>
#                         <th id="T_474155fc_bbeb_11ea_a41d_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_474155fc_bbeb_11ea_a41d_acbc32839263row1_col0" class="data row1 col0" >100%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_474155fc_bbeb_11ea_a41d_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_474155fc_bbeb_11ea_a41d_acbc32839263row2_col0" class="data row2 col0" >100%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_474155fc_bbeb_11ea_a41d_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_474155fc_bbeb_11ea_a41d_acbc32839263row3_col0" class="data row3 col0" >100%~100%</td>
#             </tr>
#     </tbody></table>

# %%
plot_custom_intervention_comparison_interactive(plot_intervention_comparison,baseline,camp_name)
# Out:
# VBox(children=(Label(value='Compare two different intervention strategies or compare a particular intervention…
